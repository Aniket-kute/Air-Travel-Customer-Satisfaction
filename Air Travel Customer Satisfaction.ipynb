# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('airline_passenger_satisfaction.csv')
df.head(50)
# Out:
#     Unnamed: 0  Gender      customer_type  age   type_of_travel  \
# 0            0    Male     Loyal Customer   13  Personal Travel
# 1            1    Male  disloyal Customer   25  Business travel
# 2            2  Female     Loyal Customer   26  Business travel
# 3            3  Female     Loyal Customer   25  Business travel
# 4            4    Male     Loyal Customer   61  Business travel
# 5            5  Female     Loyal Customer   26  Personal Travel
# 6            6    Male     Loyal Customer   47  Personal Travel
# 7            7  Female     Loyal Customer   52  Business travel
# 8            8  Female     Loyal Customer   41  Business travel
# 9            9    Male  disloyal Customer   20  Business travel
# 10          10  Female  disloyal Customer   24  Business travel
# 11          11  Female     Loyal Customer   12  Personal Travel
# 12          12    Male     Loyal Customer   53  Business travel
# 13          13    Male     Loyal Customer   33  Personal Travel
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         129880 non-null  int64
#  1   Gender                             129880 non-null  object
#  2   customer_type                      129880 non-null  object
#  3   age                                129880 non-null  int64
#  4   type_of_travel                     129880 non-null  object
#  5   customer_class                     129880 non-null  object
#  6   flight_distance                    129880 non-null  int64
#  7   inflight_wifi_service              129880 non-null  int64
#  8   departure_arrival_time_convenient  129880 non-null  int64
#  9   ease_of_online_booking             129880 non-null  int64
#  10  gate_location                      129880 non-null  int64
# ...

# %%
missing_percentage = df.isnull().sum() * 100 / len(df)
missing_percentage
# Out:
# Unnamed: 0                           0.000000
# Gender                               0.000000
# customer_type                        0.000000
# age                                  0.000000
# type_of_travel                       0.000000
# customer_class                       0.000000
# flight_distance                      0.000000
# inflight_wifi_service                0.000000
# departure_arrival_time_convenient    0.000000
# ease_of_online_booking               0.000000
# gate_location                        0.000000
# food_and_drink                       0.000000
# online_boarding                      0.000000
# seat_comfort                         0.000000
# inflight_entertainment               0.000000
# onboard_service                      0.000000
# leg_room_service                     0.000000
# baggage_handling                     0.000000
# checkin_service                      0.000000
# inflight_service                     0.000000
# ...

# %%
y = df.iloc[:,23]
x = df.drop('satisfaction',axis ='columns')

# %%
x.head(3)
# Out:
#    Unnamed: 0  Gender      customer_type  age   type_of_travel customer_class  \
# 0           0    Male     Loyal Customer   13  Personal Travel       Eco Plus
# 1           1    Male  disloyal Customer   25  Business travel       Business
# 2           2  Female     Loyal Customer   26  Business travel       Business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
#
#    ease_of_online_booking  ...  seat_comfort  inflight_entertainment  \
# 0                       3  ...             5                       5
# 1                       3  ...             1                       1
# 2                       2  ...             5                       5
#
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         129880 non-null  int64
#  1   Gender                             129880 non-null  object
#  2   customer_type                      129880 non-null  object
#  3   age                                129880 non-null  int64
#  4   type_of_travel                     129880 non-null  object
#  5   customer_class                     129880 non-null  object
#  6   flight_distance                    129880 non-null  int64
#  7   inflight_wifi_service              129880 non-null  int64
#  8   departure_arrival_time_convenient  129880 non-null  int64
#  9   ease_of_online_booking             129880 non-null  int64
#  10  gate_location                      129880 non-null  int64
# ...

# %%
x = x.drop(['Unnamed: 0'],axis='columns')

# %%
x
# Out:
#         Gender      customer_type  age   type_of_travel customer_class  \
# 0         Male     Loyal Customer   13  Personal Travel       Eco Plus
# 1         Male  disloyal Customer   25  Business travel       Business
# 2       Female     Loyal Customer   26  Business travel       Business
# 3       Female     Loyal Customer   25  Business travel       Business
# 4         Male     Loyal Customer   61  Business travel       Business
# ...        ...                ...  ...              ...            ...
# 129875    Male  disloyal Customer   34  Business travel       Business
# 129876    Male     Loyal Customer   23  Business travel       Business
# 129877  Female     Loyal Customer   17  Personal Travel            Eco
# 129878    Male     Loyal Customer   14  Business travel       Business
# 129879  Female     Loyal Customer   42  Personal Travel            Eco
#
#         flight_distance  inflight_wifi_service  \
# 0                   460                      3
# ...

# %%
x.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
x.arrival_delay_in_minutes.mean()
# Out:
# 15.09112883918849

# %%
x.arrival_delay_in_minutes.mode()
# Out:
# 0    0.0
# dtype: float64

# %%
x.arrival_delay_in_minutes=x.arrival_delay_in_minutes.fillna( x.arrival_delay_in_minutes.mode().iloc[0])

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129880 non-null  object
#  1   customer_type                      129880 non-null  object
#  2   age                                129880 non-null  int64
#  3   type_of_travel                     129880 non-null  object
#  4   customer_class                     129880 non-null  object
#  5   flight_distance                    129880 non-null  int64
#  6   inflight_wifi_service              129880 non-null  int64
#  7   departure_arrival_time_convenient  129880 non-null  int64
#  8   ease_of_online_booking             129880 non-null  int64
#  9   gate_location                      129880 non-null  int64
#  10  food_and_drink                     129880 non-null  int64
# ...

# %%
x.Gender.value_counts()
# Out:
# Female    65899
# Male      63981
# Name: Gender, dtype: int64

# %%
x.Gender = x.Gender.map({'Female':1, 'Male':0}).astype(int)

# %%
x.head(5)
# Out:
#    Gender      customer_type  age   type_of_travel customer_class  \
# 0       0     Loyal Customer   13  Personal Travel       Eco Plus
# 1       0  disloyal Customer   25  Business travel       Business
# 2       1     Loyal Customer   26  Business travel       Business
# 3       1     Loyal Customer   25  Business travel       Business
# 4       0     Loyal Customer   61  Business travel       Business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    ease_of_online_booking  gate_location  ...  seat_comfort  \
# ...

# %%
x.customer_type.unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
x.customer_type = x.customer_type.map({'Loyal Customer':1, 'disloyal Customer':0}).astype(int)

# %%
x.head(5)
# Out:
#    Gender  customer_type  age   type_of_travel customer_class  \
# 0       0              1   13  Personal Travel       Eco Plus
# 1       0              0   25  Business travel       Business
# 2       1              1   26  Business travel       Business
# 3       1              1   25  Business travel       Business
# 4       0              1   61  Business travel       Business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    ease_of_online_booking  gate_location  ...  seat_comfort  \
# 0                       3              1  ...             5
# ...

# %%
x.type_of_travel.unique()
# Out:
# array(['Personal Travel', 'Business travel'], dtype=object)

# %%
x.type_of_travel.value_counts()
# Out:
# Business travel    89693
# Personal Travel    40187
# Name: type_of_travel, dtype: int64

# %%
x.type_of_travel = x.type_of_travel.map({'Business travel':1, 'Personal Travel':0}).astype(int)

# %%
x.customer_class.value_counts()
# Out:
# Business    62160
# Eco         58309
# Eco Plus     9411
# Name: customer_class, dtype: int64

# %%
x.customer_class = x.customer_class.map({'Business':2, 'Eco Plus':1,'Eco':0}).astype(int)

# %%
y.head(5)
# Out:
# 0    neutral or dissatisfied
# 1    neutral or dissatisfied
# 2                  satisfied
# 3    neutral or dissatisfied
# 4                  satisfied
# Name: satisfaction, dtype: object

# %%
y=pd.DataFrame(y)

# %%
y.satisfaction.value_counts()
# Out:
# neutral or dissatisfied    73452
# satisfied                  56428
# Name: satisfaction, dtype: int64

# %%
y.satisfaction = y.satisfaction.map({'neutral or dissatisfied':1, 'satisfied':0}).astype(int)

# %%
y.head(5)
# Out:
#    satisfaction
# 0             1
# 1             1
# 2             0
# 3             1
# 4             0

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129880 non-null  int32
#  1   customer_type                      129880 non-null  int32
#  2   age                                129880 non-null  int64
#  3   type_of_travel                     129880 non-null  int32
#  4   customer_class                     129880 non-null  int32
#  5   flight_distance                    129880 non-null  int64
#  6   inflight_wifi_service              129880 non-null  int64
#  7   departure_arrival_time_convenient  129880 non-null  int64
#  8   ease_of_online_booking             129880 non-null  int64
#  9   gate_location                      129880 non-null  int64
#  10  food_and_drink                     129880 non-null  int64
# ...

# %%
import seaborn as sns
from pandas.plotting import scatter_matrix
# %matplotlib inline

# %%
extracted_col = y["satisfaction"]

# %%
df_1 = x.join(extracted_col)

# %%
corrmat = df_1.corr()
plt.subplots(figsize=(19,10))
sns.heatmap(corrmat, vmax=0.9, square=True, cmap ='RdBu', annot=True,fmt='.1f',linewidth = 1,linecolor ='Black')
# Out:
# <AxesSubplot:>

# %%
plt.scatter (df_1['departure_delay_in_minutes'], np.random.rand(df_1.shape[0]))
plt.scatter (df_1['arrival_delay_in_minutes'], np.random.rand(df_1.shape[0]))

# %%
df_1
# Out:
#         Gender  customer_type  age  type_of_travel  customer_class  \
# 0            0              1   13               0               1
# 1            0              0   25               1               2
# 2            1              1   26               1               2
# 3            1              1   25               1               2
# 4            0              1   61               1               2
# ...        ...            ...  ...             ...             ...
# 129875       0              0   34               1               2
# 129876       0              1   23               1               2
# 129877       1              1   17               0               0
# 129878       0              1   14               1               2
# 129879       1              1   42               0               0
#
#         flight_distance  inflight_wifi_service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %%
print ((df_1['arrival_delay_in_minutes']> 600).sum())
print ((df_1['departure_delay_in_minutes']> 500).sum())
# Out:
# 25
# 43

# %%
df_1 = df_1[(df_1['departure_delay_in_minutes'] <= 500)]

# %%
plt.scatter (df_1['departure_delay_in_minutes'], np.random.rand(df_1.shape[0]))
plt.scatter (df_1['arrival_delay_in_minutes'], np.random.rand(df_1.shape[0]))

# %%
df_1 = df_1.drop(['arrival_delay_in_minutes'],axis='columns')

# %%
df_2=df_1

# %%
df_2
# Out:
#         Gender  customer_type  age  type_of_travel  customer_class  \
# 0            0              1   13               0               1
# 1            0              0   25               1               2
# 2            1              1   26               1               2
# 3            1              1   25               1               2
# 4            0              1   61               1               2
# ...        ...            ...  ...             ...             ...
# 129875       0              0   34               1               2
# 129876       0              1   23               1               2
# 129877       1              1   17               0               0
# 129878       0              1   14               1               2
# 129879       1              1   42               0               0
#
#         flight_distance  inflight_wifi_service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_2[["flight_distance","departure_delay_in_minutes"]] = sc.fit_transform(df_2[["flight_distance",
"departure_delay_in_minutes"]])
df_2
# Out:
#         Gender  customer_type  age  type_of_travel  customer_class  \
# 0            0              1   13               0               1
# 1            0              0   25               1               2
# 2            1              1   26               1               2
# 3            1              1   25               1               2
# 4            0              1   61               1               2
# ...        ...            ...  ...             ...             ...
# 129875       0              0   34               1               2
# 129876       0              1   23               1               2
# 129877       1              1   17               0               0
# 129878       0              1   14               1               2
# 129879       1              1   42               0               0
#
#         flight_distance  inflight_wifi_service  \
# 0             -0.732114                      3
# 1             -0.957690                      3
# ...

# %%
y = df_2.iloc[:,21]
x = df_2.drop('satisfaction',axis ='columns')
y = pd.DataFrame(y)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129837 entries, 0 to 129879
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129837 non-null  int32
#  1   customer_type                      129837 non-null  int32
#  2   age                                129837 non-null  int64
#  3   type_of_travel                     129837 non-null  int32
#  4   customer_class                     129837 non-null  int32
#  5   flight_distance                    129837 non-null  float64
#  6   inflight_wifi_service              129837 non-null  int64
#  7   departure_arrival_time_convenient  129837 non-null  int64
#  8   ease_of_online_booking             129837 non-null  int64
#  9   gate_location                      129837 non-null  int64
#  10  food_and_drink                     129837 non-null  int64
# ...

# %%
y
# Out:
#         satisfaction
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  0
# ...              ...
# 129875             1
# 129876             0
# 129877             1
# 129878             0
# 129879             1
#
# [129837 rows x 1 columns]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42)
print(np.mean(y_train), np.mean(y))
# Out:
# satisfaction    0.566606
# dtype: float64 satisfaction    0.565509
# dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
logreg.coef_

print("Accuracy is:", logreg.score(x_test, y_test))
# Out:
# Accuracy is: 0.8728178270692134

# %%
y_pred = logreg.predict(x_test)
np.sum(y_test ==  y_pred)/y_test.shape[0]
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ANIKET~1\AppData\Local\Temp/ipykernel_32812/1875209565.py in <module>
#       1 y_pred = logreg.predict(x_test)
# ----> 2 np.sum(y_test ==  y_pred)/y_test.shape[0]
#       3 warnings.filterwarnings('ignore')
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _cmp_method(self, other, op)
# ...

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
print('Precision score:', precision_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('F1 score:', f1_score(y_test, y_pred))
# Out:
# Precision score: 0.8754977435625166
# Recall score: 0.9024078803356439
# Accuracy score: 0.8728178270692134
# F1 score: 0.8887491578710982

# %%
# Practice 1: Here we plot the Precision-Recall Curve

from sklearn.metrics import precision_recall_curve

# S1. Get probability
logreg_prob = logreg.predict_proba(x_test)[ : , 1 ]

# S2. Collect Necessary Measures
precision, recall, threshold = precision_recall_curve(y_test, logreg_prob)

# S3. Plot Figure

plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
# Out:
# Text(0, 0.5, 'Precision')

# %%
from sklearn.metrics import roc_auc_score

# we have obtained the predicted probability in the previous step: y_pred_proba

print("AUC for logistic regression:",  roc_auc_score(y_test, logreg_prob) )
# Out:
# AUC for logistic regression: 0.9261479635462813

# %%
# Practice 2: Similar to Precision-Recall Curve

from sklearn.metrics import roc_curve

# Predicted Probability: y_pred_proba
# Get Measures
fpr, tpr, threshold= roc_curve(y_test, logreg_prob)


# Generate Figure

plt.plot(fpr, tpr)
plt.xlabel("FPR")
plt.ylabel("TPR")
# Out:
# Text(0, 0.5, 'TPR')

# %%
# %matplotlib inline
# import necessary libraries and specify that graphs should be plotted inline. 
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.model_selection import train_test_split

# Split data into training and test, if test size is not specified, default value  of 0.25 is applied
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state = 0, criterion = 'entropy')

dt.fit(x_train, y_train)
dt.score(x_train, y_train), dt.score(x_test, y_test)
# Out:
# (1.0, 0.9493222427603204)

# %%
# GridSearch + CV
from sklearn.model_selection import GridSearchCV

# estimator
opt_tree = DecisionTreeClassifier(random_state = 0) # for all hyperparameters, apply the same setting

# hyperparameters (multiple)
dt_params = {'max_depth':  range(1,10)         ,
             'min_samples_split':   range(2,11),
             'max_leaf_nodes':    range(2,11)   }

# GridsearchCV
grid_tree = GridSearchCV(opt_tree, dt_params)

grid_tree.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(random_state=0),
#              param_grid={'max_depth': range(1, 10),
#                          'max_leaf_nodes': range(2, 11),
#                          'min_samples_split': range(2, 11)})

# %%
# Report the best hyperparameters chosen

grid_tree.best_params_
# Out:
# {'max_depth': 5, 'max_leaf_nodes': 9, 'min_samples_split': 2}

# %%
`
# Out:
# 0.8929086207845078

# %%
dt_depth = DecisionTreeClassifier(criterion ='gini', max_depth= 5, max_leaf_nodes= 9, min_samples_split= 2)
dt_depth.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, max_leaf_nodes=9)

# %%
# Plot the decision tree

from sklearn import tree
fig = plt.figure(figsize=(20,10)) # set a proper figure size (in case that the figure is too small to read or ratio is not proper)

tree.plot_tree(grid_tree.best_estimator_, 
               feature_names = x.columns, # specify variable names 
             # specify class (Y) names
               filled = True, impurity = False) # whether to color the boxes, whether to report gini index
             #   fontsize = 12) # set fontsize to read
plt.show()

# save the figure to read through the boxes, it is saved under the same directory as the coding doc.
# fig.savefig("grid_tree.jpg")

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
def scores(dt_depth):
    y_train_pred = dt_depth.predict(x_train)
    y_test_pred = dt_depth.predict(x_test)
    train_score = accuracy_score(y_train,y_train_pred)
    test_score= accuracy_score(y_test,y_test_pred)
    cm = confusion_matrix(y_test,y_test_pred)
    print("train_score",train_score)
    print("test-score",test_score)
    print(cm)
    print(classification_report(y_test,y_test_pred))

# %%
 scores(dt_depth)
# Out:
# train_score 0.8973427958408978
# test-score 0.897181146025878
# [[15337  1687]
#  [ 2318 19610]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88     17024
#            1       0.92      0.89      0.91     21928
#
#     accuracy                           0.90     38952
#    macro avg       0.89      0.90      0.90     38952
# weighted avg       0.90      0.90      0.90     38952

# %% [markdown]
# # knn with grid search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# define function

knn = KNeighborsClassifier()


# define a list of parameters
param_knn = { 
         'n_neighbors': np.arange(1,10),
         'metric': ["minkowski","manhattan"]
}

#apply grid search

grid_knn = GridSearchCV( knn , param_knn, cv = 5)

grid_knn.fit(x_train, y_train)

# the best hyperparameter chosen:
print(grid_knn.best_params_)

# When k=25 (best case), the validation score of through CV is:
print(grid_knn.best_score_)


grid_knn.score(x_test, y_test)

# %%
#voting classifier

# %%
# Linear SVC 
from sklearn.svm import LinearSVC

lr_svc = LinearSVC(random_state = 22)

lr_svc.fit(x_train, y_train)
lr_svc.score(x_test, y_test)

# %%
from sklearn.svm import SVC

svm_clf = SVC(kernel = 'rbf', C = 1, random_state = 0)

svm_clf.fit(x_train, y_train)

svm_clf.score(x_test, y_test)

# %%
#k means

# %%
x1=x
y2=y

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x1)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x1)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
kmeans.fit(x)

cls_predict = kmeans.predict(x1)
print("Predicted Labels:", cls_predict)
print("Performance Score:", kmeans.score(x1))
print("Cluster Centers: \n", kmeans.cluster_centers_)
# Out:
# Predicted Labels: [0 0 0 ... 0 0 3]
# Performance Score: -6392923.746209883
# Cluster Centers:
#  [[ 5.18836631e-01  6.21875370e-01  2.01237116e+01  6.07125933e-01
#    6.95563322e-01 -2.30743771e-01  2.67533468e+00  2.97473641e+00
#    2.69245350e+00  2.96768748e+00  3.12791731e+00  2.79649923e+00
#    3.08790428e+00  3.14311101e+00  3.23418434e+00  3.21143822e+00
#    3.68830707e+00  3.23234806e+00  3.69692572e+00  3.14124511e+00
#    1.15908763e-02]
#  [ 5.02383515e-01  9.57212056e-01  6.04755113e+01  5.93649085e-01
#    1.00211441e+00  1.83604094e-02  2.69406428e+00  3.19817776e+00
#    2.73931262e+00  2.96409350e+00  3.19787021e+00  3.46947563e+00
#    3.60625865e+00  3.37217438e+00  3.39458711e+00  3.31293249e+00
#    3.52379671e+00  3.32227433e+00  3.52544979e+00  3.30113025e+00
#   -1.07953240e-02]
#  [ 5.02951172e-01  7.80689203e-01  3.45687414e+01  7.56960591e-01
#    1.12874858e+00  8.09212920e-03  2.72664401e+00  3.00742264e+00
# ...

# %%
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %%
# dbscan

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(x1)
print(clusters)
# Out:
# [-1 -1 -1 ... -1 -1 -1]

# %%
x2=x
y2=y

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x2)
X_scaled = scaler.transform(x2)

# %%
# S2: Apply DBSCAN
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(X_scaled)
print(clusters)
# Out:
# [-1 -1 -1 ... -1 -1 -1]

# %%
# S3: plot the cluster assignments
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, s=60)

# %%
dbscan = DBSCAN(eps=5, min_samples=70)
model = dbscan.fit(X_scaled)
labels_db = model.labels_

# %%
dbscan_pred = dbscan.fit_predict(X_scaled)
dbscan_clstrs = np.unique(dbscan_pred)
dbscan_clstrs

# %%
# !pip install kmodes

# %%
import numpy as np
import pandas as pd
from kmodes.kprototypes import KPrototypes

# %%
mark_array=x.values

# %%
categorical_features_idx = [1,2,4,5]

# %%
kproto = KPrototypes(n_clusters=2, verbose=2, max_iter=5).fit(mark_array, categorical=categorical_features_idx)
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/5, moves: 43660, ncost: 3133282.7656816025
# Run: 1, iteration: 2/5, moves: 23399, ncost: 3029838.770180914
# Run: 1, iteration: 3/5, moves: 6188, ncost: 3022792.7726108646
# Run: 1, iteration: 4/5, moves: 1504, ncost: 3022373.956273343
# Run: 1, iteration: 5/5, moves: 377, ncost: 3022347.8229063014
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/5, moves: 42418, ncost: 3080732.8255785955
# Run: 2, iteration: 2/5, moves: 16970, ncost: 3026308.748527119
# Run: 2, iteration: 3/5, moves: 4634, ncost: 3022600.6196216415
# Run: 2, iteration: 4/5, moves: 1156, ncost: 3022364.7124100304
# Run: 2, iteration: 5/5, moves: 319, ncost: 3022346.8554442544
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# ...

# %%
print(kproto.cluster_centroids_)
# Out:
# [[ 5.11265435e-01  6.07138528e-01  2.27435360e+00  2.92234557e+00
#    2.47694093e+00  2.93432970e+00  2.36456367e+00  2.57312575e+00
#    2.51297993e+00  2.22466793e+00  2.79323901e+00  2.87349116e+00
#    3.14675372e+00  2.92591310e+00  3.14973244e+00  2.32010807e+00
#    4.37738645e-02  1.00000000e+00  2.50000000e+01  0.00000000e+00
#   -8.55428703e-01]
#  [ 5.04327683e-01  7.57413932e-01  3.09278165e+00  3.16593614e+00
#    2.98126058e+00  3.01123533e+00  3.87800649e+00  3.79707049e+00
#    4.18511943e+00  4.26599994e+00  3.85554970e+00  3.73307071e+00
#    4.02093101e+00  3.61100785e+00  4.03697950e+00  4.06029628e+00
#   -3.50602583e-02  1.00000000e+00  3.90000000e+01  2.00000000e+00
#   -8.55428703e-01]]

# %%
clusters = kproto.predict(mark_array, categorical=categorical_features_idx)

# %%
clusters
# Out:
# array([1, 0, 1, ..., 0, 1, 0], dtype=uint16)

# %%
df['cluster'] = list(clusters)

# %%
#random forest

# %%
from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier(n_estimators=200, random_state=42)
rnd_clf.fit(x_train, y_train)

print(rnd_clf.score(x_test, y_test))
# Out:
# 0.9643920722941056

# %%
from sklearn.ensemble import AdaBoostClassifier

# Define base model
naive_dt = DecisionTreeClassifier(max_depth=1)

# AdaBoost
ada_clf = AdaBoostClassifier(
    naive_dt, n_estimators=200, learning_rate=0.5,
    random_state=42)

ada_clf.fit(x_train, y_train)

# Performance
print(ada_clf.score(x_test, y_test))
# Out:
# 0.9295799958923804

# %%
# S1: Define Functions/Estimators

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

log_clf = LogisticRegression(random_state=42)
svm_clf = SVC(kernel = 'rbf', random_state=42) 
nbg_clf = GaussianNB()

# %%
# S2: Apply Voting Classifier

from sklearn.ensemble import VotingClassifier

# define voting classifier
voting_clf = VotingClassifier(
    estimators=[('lr1', log_clf), ('svc', svm_clf), ('nbg', nbg_clf)],
    voting='hard')

# train the model
voting_clf.fit(x_train, y_train)

# Performance Measure
print("Test score for voting classifier is:", voting_clf.score(x_test, y_test))
# Out:
# Test score for voting classifier is: 0.8848069418771821

# %%
for clf in (log_clf, nbg_clf, svm_clf, voting_clf):
    clf.fit(x_train, y_train)
    print(clf.__class__.__name__, clf.score(x_test, y_test))
# Out:
# LogisticRegression 0.8728178270692134
# GaussianNB 0.8653727664818238
# SVC 0.8995686999383857
# VotingClassifier 0.8848069418771821

# %%
import sklearn.metrics as metrics
from sklearn.metrics import classification_report
def scores(voting_clf):
    y_train_pred_2 = voting_clf.predict(x_train)
    y_test_pred_2 = voting_clf.predict(x_test)
    train_score_2 = accuracy_score(y_train,y_train_pred_2)
    test_score_2= accuracy_score(y_test,y_test_pred_2)
    cm_2 = confusion_matrix(y_test,y_test_pred_2)
    
    print("train_score",train_score_2)
    print("test-score",test_score_2)
    print(cm_2)
    print(classification_report(y_test,y_test_pred_2))

# %%
scores(voting_clf)
# Out:
# train_score 0.886482917973263
# test-score 0.8848069418771821
# [[14251  2773]
#  [ 1714 20214]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86     17024
#            1       0.88      0.92      0.90     21928
#
#     accuracy                           0.88     38952
#    macro avg       0.89      0.88      0.88     38952
# weighted avg       0.89      0.88      0.88     38952
